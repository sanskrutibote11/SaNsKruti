# %% [markdown]
# <a href="https://colab.research.google.com/github/sanskrutibote11/SaNsKruti/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=(input("length of string"))
print(a)

a=input("enter first string")
b=input("enter second string")
c= a+b
print(c)

a="Sanskruti"
b="bote"
c=a+b
print(c)
# Out:
# length of string11
# 11
# enter first string Atharv
# enter second string Bote
#  Atharv  Bote
# Sanskrutibote
